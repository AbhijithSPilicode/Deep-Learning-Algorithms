# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\user\\Downloads\\hourly_wages.csv")
data
# Out:
#      wage_per_hour  union  education_yrs  experience_yrs  age  female  marr  \
# 0             5.10      0              8              21   35       1     1
# 1             4.95      0              9              42   57       1     1
# 2             6.67      0             12               1   19       0     0
# 3             4.00      0             12               4   22       0     0
# 4             7.50      0             12              17   35       0     1
# ..             ...    ...            ...             ...  ...     ...   ...
# 529          11.36      0             18               5   29       0     0
# 530           6.10      0             12              33   51       1     1
# 531          23.25      1             17              25   48       1     1
# 532          19.88      1             12              13   31       0     1
# 533          15.38      0             16              33   55       0     1
#
#      south  manufacturing  construction
# ...

# %%
from keras.models import Sequential #2 type model:sequential and functional API
from keras.layers import Dense
#sequential adding layers in stacking up

# %%
model=Sequential()

# %%
data.shape
# Out:
# (534, 10)

# %%
#output of first layer is input of second layer

# %%
X=data.drop(columns=['wage_per_hour'])
X
# Out:
#      union  education_yrs  experience_yrs  age  female  marr  south  \
# 0        0              8              21   35       1     1      0
# 1        0              9              42   57       1     1      0
# 2        0             12               1   19       0     0      0
# 3        0             12               4   22       0     0      0
# 4        0             12              17   35       0     1      0
# ..     ...            ...             ...  ...     ...   ...    ...
# 529      0             18               5   29       0     0      0
# 530      0             12              33   51       1     1      0
# 531      1             17              25   48       1     1      0
# 532      1             12              13   31       0     1      1
# 533      0             16              33   55       0     1      0
#
#      manufacturing  construction
# 0                1             0
# 1                1             0
# 2                1             0
# ...

# %%
y=data[['wage_per_hour']]
y
# Out:
#      wage_per_hour
# 0             5.10
# 1             4.95
# 2             6.67
# 3             4.00
# 4             7.50
# ..             ...
# 529          11.36
# 530           6.10
# 531          23.25
# 532          19.88
# 533          15.38
#
# [534 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
n_cols=X_train.shape[1]

# %%
#creating model with layers
model.add(Dense(10,activation="relu",input_shape=(n_cols,))) #relu is used for non linear relationships #input layer
model.add(Dense(10,activation="relu")) #10 is number of nodes in layer
model.add(Dense(1)) #only 1 node in prediction

# %%
#congigure model
model.compile(optimizer="adam",loss="mean_squared_error") #adam is a commonly used optimizer,learning rate is higher in adam

# %%
#training the model
from keras.callbacks import EarlyStopping
early_stop=EarlyStopping(patience=3) #patience means after 3 epoch,if there is no improvement in training it will stop there
model.fit(X_train,y_train,epochs=100,callbacks=[early_stop]) #epochs=no.of iteration
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 1ms/step - loss: 267.9328
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 2/100
# 14/14 [==============================] - 0s 3ms/step - loss: 208.6323
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 166.9591
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 139.0099
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 5/100
# 14/14 [==============================] - 0s 1ms/step - loss: 119.1527
# ...

# %%
model.predict(X_test)
# Out:
# array([[ 4.2627106],
#        [11.196171 ],
#        [ 7.787428 ],
#        [ 9.357931 ],
#        [ 8.152489 ],
#        [10.299875 ],
#        [ 8.492647 ],
#        [ 8.278285 ],
#        [ 8.597292 ],
#        [ 7.6103373],
#        [ 7.1549463],
#        [ 8.611483 ],
#        [ 9.465087 ],
#        [12.320375 ],
#        [ 7.715591 ],
#        [12.322075 ],
#        [ 6.6293573],
#        [ 9.167793 ],
#        [10.055126 ],
#        [ 7.9997067],
#        [10.053516 ],
#        [ 5.5839   ],
#        [ 9.956919 ],
#        [11.157943 ],
#        [10.4491825],
#        [ 8.403465 ],
#        [ 8.070974 ],
#        [ 9.707055 ],
#        [ 8.031531 ],
#        [ 9.6229105],
#        [ 9.807874 ],
#        [ 6.7777147],
#        [10.323934 ],
#        [ 8.771923 ],
#        [ 9.065697 ],
#        [12.965119 ],
#        [ 8.77556  ],
#        [ 8.866256 ],
#        [ 7.698719 ],
#        [ 9.921561 ],
#        [ 8.893224 ],
#        [11.210798 ],
#        [ 7.25543  ],
# ...

# %%
y_test
# Out:
#      wage_per_hour
# 298           5.00
# 510           9.50
# 172          11.25
# 408           5.77
# 225           5.65
# ..             ...
# 503           4.35
# 389           3.75
# 62            7.00
# 271           5.21
# 400          10.00
#
# [107 rows x 1 columns]
